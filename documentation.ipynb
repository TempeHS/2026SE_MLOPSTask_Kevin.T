# %% [markdown]
# ### data wrangling
#
# When wrangling the data, the main things that I would do is drop the unneccessary columns and also one hot encode the strings into integers such as the track type. I used the 2.12 data wrangling file and removed all of the steps that I thought weren't relevant to my project (data scaling, removing outliers, removing duplicates)

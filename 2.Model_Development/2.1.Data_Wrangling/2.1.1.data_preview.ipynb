# %% [markdown]
# [Home](../../README.md)
#
# ### Data Preprocessing
#
# This Jupyter Notebook demonstrates different processes you can apply to your data to better understand it before data wrangling.

# %% [markdown]
# #### Load the required dependencies
#
# Load the two required dependencies:
#
# - [Numpy](https://numpy.org/doc/stable/) is a library that enables numerical computing with Python
# - [Pandas](https://pandas.pydata.org/) is library for data analysis and manipulation.
# - [Matplotlib](https://matplotlib.org) a comprehensive library for creating static, animated, and interactive visualizations in Python. A customised stylesheet for the visualisations is also applied.

# %%
# Import frameworks
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('../../style_Matplotlib_charts.mplstyle')

# %% [markdown]
# ####  Store the data as a local variable
#
# The data frame is a Pandas object that structures your tabular data into an appropriate format. It loads the complete data in memory so it is now ready for preprocessing.

# %%
data_frame = pd.read_csv("NASCAR 2017-2024 Full Race  Points Data - Cup.csv")

# %% [markdown]
# #### Data Snapshot
#
# It is important to get a high-level look at your dataset to understand what you are working with. Printing the complete data might be impossible for large-scale datasets where the rows can be in thousands or even millions.
#
# You can use the `head()` and `tail()` method call to inspect the first and last 5 rows of your dataset.

# %%
# Target = A measure of disease progression in one year
data_frame.head()
# Out:
#    year  race_num    track     track_type  fin  start  car_num  \
# 0  2017        -1  Daytona  superspeedway    1      1       24
# 1  2017        -1  Daytona  superspeedway    2     12        1
# 2  2017        -1  Daytona  superspeedway    3      4        4
# 3  2017        -1  Daytona  superspeedway    4      2        2
# 4  2017        -1  Daytona  superspeedway    5      5       20
#
#             driver       manu             team_name  laps  laps_led   status  \
# 0    Chase Elliott  Chevrolet  Hendrick Motorsports    60        25  running
# 1   Jamie McMurray  Chevrolet   Chip Ganassi Racing    60         0  running
# 2    Kevin Harvick       Ford   Stewart-Haas Racing    60         0  running
# 3  Brad Keselowski       Ford           Team Penske    60        28  running
# 4     Matt Kenseth     Toyota      Joe Gibbs Racing    60         0  running
#
#    points  stage_1  stage_2  stage_3_or_duel stage_points
# 0     NaN      NaN      NaN              1.0           10
# 1     NaN      NaN      NaN              2.0            9
# 2     NaN      NaN      NaN              3.0            8
# 3     NaN      NaN      NaN              4.0            7
# 4     NaN      NaN      NaN              5.0            6

# %% [markdown]
# ####  Data Summary
#
# The `info()` method call prints a summary of each column, giving you more information about the specific data types, total number of rows, null values and memory usage.

# %%
data_frame.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 11325 entries, 0 to 11324
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   year             11325 non-null  int64
#  1   race_num         11325 non-null  int64
#  2   track            11325 non-null  str
#  3   track_type       11325 non-null  str
#  4   fin              11325 non-null  int64
#  5   start            11325 non-null  int64
#  6   car_num          11325 non-null  int64
#  7   driver           11325 non-null  str
#  8   manu             11325 non-null  str
#  9   team_name        11325 non-null  str
#  10  laps             11325 non-null  int64
#  11  laps_led         11325 non-null  int64
#  12  status           11325 non-null  str
#  13  points           10988 non-null  float64
#  14  stage_1          8513 non-null   float64
#  15  stage_2          8513 non-null   float64
#  16  stage_3_or_duel  412 non-null    float64
#  17  stage_points     11325 non-null  str
# dtypes: float64(4), int64(7), str(7)
# memory usage: 1.6 MB

# %% [markdown]
# #### Statistics For Numerical Columns
#
# The `describe()` method call provides basic statistical knowledge like the mean and spread of the data.

# %%
data_frame.describe()
# Out:
#                year      race_num           fin         start       car_num  \
# count  11325.000000  11325.000000  11325.000000  11325.000000  11325.000000
# mean    2020.456071     17.949934     19.350817     19.355673     29.818190
# std        2.290987     10.798926     11.042055     11.040368     24.793197
# min     2017.000000     -2.000000      1.000000      1.000000      0.000000
# 25%     2018.000000      9.000000     10.000000     10.000000     11.000000
# 50%     2020.000000     18.000000     19.000000     19.000000     22.000000
# 75%     2022.000000     27.000000     29.000000     29.000000     43.000000
# max     2024.000000     36.000000     40.000000     40.000000     99.000000
#
#                laps      laps_led        points      stage_1      stage_2  \
# count  11325.000000  11325.000000  10988.000000  8513.000000  8513.000000
# mean     249.936865      7.037616     19.604751    18.061083    18.061083
# std      124.110994     26.166353     14.821091    11.271305    11.271305
# min        0.000000      0.000000    -37.000000     1.000000     1.000000
# 25%      160.000000      0.000000      7.000000     8.000000     8.000000
# 50%      264.000000      0.000000     18.000000    17.000000    17.000000
# 75%      325.000000      0.000000     30.000000    28.000000    28.000000
# max      505.000000    464.000000     70.000000    40.000000    40.000000
#
#        stage_3_or_duel
# count       412.000000
# mean         13.584951
# std          11.192197
# min           1.000000
# 25%           5.000000
# 50%           9.000000
# 75%          22.000000
# max          40.000000

# %% [markdown]
# #### The data columns are:
#
# | Column | Data |
# | ------ | -----|
# | year | Year of the race |
# | race_num | The order in the season that the race took place |
# | track | The racetrack used |
# | track_type | The type of track e.g. superspeedway, speedway, short track, road course |
# | fin | Finishing position
# | start | Starting/qualifying position
# | car_num | The number that the driver has on their car |
# | driver | The driver of the car |
# | manu | The manufacturer of the car (Toyota, Chevrolet or Ford) |
# | team_name | The name of the driver's team |
# | laps | How many laps the driver completed in the race |
# | laps_led | How many laps the driver led the field in the race |
# | status | The status of the car (if they were running or in an accident and DNFed) |
# | points | How many points the driver got from the race |
# | stage_1 | Finishing position in stage 1 |
# | stage_2 | Finishing position in stage 2 |
# | stage_3_or_duel | Finishing position in stage 3 (only in coca cola 600 or the duel) |
# | stage_points | Total stage points earned in the race |
#
#
# From this data, I will most likely not use these columns as they won't be useful for predictions:
# - year
# - race num
# - car num
# - driver
# - team name
# - laps
# - status
# - points
# - stages and stage points
#
# I have designed the model to have the car manufacturer, starting position and track inputted and predicting the finishing positon based on these. I won't make it so the driver of the car could be chosen due to how complex it would make the model, so I chose less and simpler features instead.

# %% [markdown]
# #### Graphically present the data
#
# At this early stage you are just wanting to evaluate the data, the below simple plots lets you look the data in different ways to inform your model design and data wrangling approaches.

# %%
# plot a line graph 
data_frame.plot(lw=1)
# Out:
# <Axes: >

# %%
# Plot a histogram of a column
plt.hist(data_frame['points'], bins=300)
plt.title(f"Histogram of {data_frame['points'].name}")
plt.ylabel('Count')
plt.xlabel(f'{data_frame["points"].name}')
plt.show()

# %%
# # Scatter plot 2 columns to see the relationship
# plt.scatter(data_frame["fin"], data_frame["start"], s=1)
# plt.title(f"Scatter of {data_frame['fin'].name} against {data_frame['start'].name}")
# plt.ylabel(f"{data_frame['start'].name} Data")
# plt.xlabel(f"{data_frame['fin'].name} Data")
# plt.show()

wins_by_driver = (
    data_frame.loc[data_frame["fin"] == 1, "driver"]
    .value_counts()
    .sort_values(ascending=False)
)

plt.figure(figsize=(14, 10))
wins_by_driver.plot(kind="barh")  # swapped axes
plt.title("Wins by Driver (2017-2024)")
plt.xlabel("Number of Wins")
plt.ylabel("Driver")
plt.gca().invert_yaxis()  # keeps highest wins at the top
plt.tight_layout()
plt.show()

# %%
# Scatter plot multiples columns to see the relationship
x_plot = ['start', 'laps_led']
for col in x_plot:
    plt.scatter(data_frame[col], data_frame['fin'], marker='x', s=1)
plt.title(f"Scatter of {*x_plot,} against {data_frame['fin'].name}")
plt.ylabel(f"{data_frame['fin'].name} Data")
plt.xlabel(f"{*x_plot,} Data")
plt.show()

# %%
# Scatter plot 2 columns in separate charts with a shared y-axis
fig, (ax1, ax2) = plt.subplots(1,2, sharey=True)
plt.suptitle(f"Scatter of {data_frame['start'].name} and {data_frame['laps_led'].name} against {data_frame['fin'].name}")
ax1.set_ylabel(f"{data_frame['fin'].name} Data")

ax1.scatter(data_frame["start"], data_frame["fin"])
ax1.set_xlabel(f"{data_frame['start'].name} Data")

ax2.scatter(data_frame["laps_led"], data_frame["fin"])
ax2.set_xlabel(f"{data_frame['laps_led'].name} Data")

plt.show()
